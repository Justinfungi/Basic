# %% [markdown]
# # Import

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
# %reload_ext autoreload
# %autoreload 2

# %%
df = pd.read_csv("5000 Sales Records.csv")
df
# Out:
#                                  Region               Country   Item Type  \
# 0     Central America and the Caribbean  Antigua and Barbuda    Baby Food
# 1     Central America and the Caribbean                Panama      Snacks
# 2                                Europe        Czech Republic   Beverages
# 3                                  Asia           North Korea      Cereal
# 4                                  Asia             Sri Lanka      Snacks
# ...                                 ...                   ...         ...
# 4995              Australia and Oceania           New Zealand   Household
# 4996       Middle East and North Africa            Azerbaijan     Clothes
# 4997                               Asia               Myanmar   Baby Food
# 4998                             Europe               Finland     Clothes
# 4999                 Sub-Saharan Africa              Tanzania  Vegetables
#
#      Sales Channel Order Priority  Order Date   Order ID   Ship Date  \
# ...

# %%
df1 = sns.load_dataset("car_crashes")
df1
# Out:
#     total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0    18.8     7.332    5.640          18.048       15.040       784.55
# 1    18.1     7.421    4.525          16.290       17.014      1053.48
# 2    18.6     6.510    5.208          15.624       17.856       899.47
# 3    22.4     4.032    5.824          21.056       21.280       827.34
# 4    12.0     4.200    3.360          10.920       10.680       878.41
# 5    13.6     5.032    3.808          10.744       12.920       835.50
# 6    10.8     4.968    3.888           9.396        8.856      1068.73
# 7    16.2     6.156    4.860          14.094       16.038      1137.87
# 8     5.9     2.006    1.593           5.900        5.900      1273.89
# 9    17.9     3.759    5.191          16.468       16.826      1160.13
# 10   15.6     2.964    3.900          14.820       14.508       913.15
# 11   17.5     9.450    7.175          14.350       15.225       861.18
# ...

# %%
df2 = sns.load_dataset("tips")
df2
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df2.to_excel("sales.xlsx", encoding='utf-8', index=False)

# %%
df3 = sns.load_dataset("flights")
df3
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %% [markdown]
# # Palatte

# %% [markdown]
# https://seaborn.pydata.org/_images/color_palettes_22_0.png

# %% [raw]
# from PIL import Image
# import requests
# from io import BytesIO
#
# url="https://seaborn.pydata.org/_images/color_palettes_22_0.png"
# response = requests.get(url)
# img = Image.open(BytesIO(response.content))
# img.show()

# %%
from IPython.display import Image
from IPython.core.display import HTML 
Image(url= "https://seaborn.pydata.org/_images/color_palettes_22_0.png")
# Out:
# <img src="https://seaborn.pydata.org/_images/color_palettes_22_0.png"/>

# %% [raw]
# https://seaborn.pydata.org/tutorial/color_palettes.html

# %% [markdown]
# 感知统一的调色板
# 因为m它们旨在表示数值，所以最好的顺序调色板在感知上是统一的，这意味着两种颜色的相对可辨别性与相应数据值之间的差异成正比。Seaborn 包括四个感知统一的顺序颜色图："rocket"、"mako"、"flare"和"crest"。前两个具有非常宽的亮度范围，非常适合诸如热图之类的应用，其中颜色填充了它们被绘制到的空间：

# %%
sns.color_palette("rocket", as_cmap=True)

# %% [markdown]
# # Plot

# %% [markdown]
# ## Distribution

# %%
plt.figure(figsize=[5,3], dpi=1080)
plt.plot("total","alcohol",data=df1)

# %%
sns.displot(df1["not_distracted"],kde=True,bins=25)
#kde stand for kernel estimation

# %% [markdown]
# ## Joint Plot

# %%
sns.jointplot(x="speeding",y="alcohol",data=df1,kind="reg")
#scatter" | "kde" | "hist" | "hex" | "reg" | "resid"

# %% [markdown]
# ## KDE plot

# %%
sns.kdeplot(df1["alcohol"])
# Out:
# <AxesSubplot:xlabel='alcohol', ylabel='Density'>

# %%
#Pair Plot

# %%
sns.pairplot(df1)

# %%
df2
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.pairplot(df2, hue="sex",palette="rocket")

# %% [markdown]
# ## Rug plot

# %%
sns.rugplot(df2.tip)
# Out:
# <AxesSubplot:xlabel='tip'>

# %%
# Styling

# %%
#grid style
sns.set_style("ticks")

#size of graaph
plt.figure(figsize=(16,4))

#text style
sns.set_context("paper",font_scale=1.4)

#the axes line can be seen or not
# sns.despint()


sns.jointplot(x="speeding",y="alcohol",data=df1,kind="reg")

# %% [markdown]
# # Categories plot

# %% [markdown]
# ## Bar plot

# %%
sns.barplot(x="sex",y="total_bill", data = df2, estimator=np.cov)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='total_bill'>

# %% [markdown]
# ## Count plot

# %%
sns.countplot(x='sex',data = df2)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %% [markdown]
# ## Box plot

# %%
sns.boxplot(x="day",y="total_bill", data = df2, hue="sex")
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.boxplot(x="day",y="total_bill", data = df2, hue="sex")
plt.legend(loc=0)

# %% [markdown]
# ## Violin plot

# %%
sns.violinplot(x="day",y="total_bill", data = df2, hue="sex",split=True)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %% [markdown]
# # Strip plot

# %%
plt.figure(figsize=(16,4))
sns.stripplot(x="day",y="total_bill", data = df2, 
              hue="sex", jitter=True)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %% [markdown]
# ## Swarm plot

# %%
sns.violinplot(x="day",y="total_bill", data = df2, hue="sex",split=True)
sns.swarmplot(x="day",y="total_bill", data = df2,palette="afmhot")

plt.legend(loc=4)

# %% [markdown]
# # Matrix plot

# %% [markdown]
# ## Heatmaps

# %%
plt.figure(figsize=(8,6))
sns.set_context("paper", font_scale=1.4)

crash_mx=df1.corr()
crash_mx
# Out:
#                    total  speeding   alcohol  not_distracted  no_previous  \
# total           1.000000  0.611548  0.852613        0.827560     0.956179
# speeding        0.611548  1.000000  0.669719        0.588010     0.571976
# alcohol         0.852613  0.669719  1.000000        0.732816     0.783520
# not_distracted  0.827560  0.588010  0.732816        1.000000     0.747307
# no_previous     0.956179  0.571976  0.783520        0.747307     1.000000
# ins_premium    -0.199702 -0.077675 -0.170612       -0.174856    -0.156895
# ins_losses     -0.036011 -0.065928 -0.112547       -0.075970    -0.006359
#
#                 ins_premium  ins_losses
# total             -0.199702   -0.036011
# speeding          -0.077675   -0.065928
# alcohol           -0.170612   -0.112547
# not_distracted    -0.174856   -0.075970
# no_previous       -0.156895   -0.006359
# ins_premium        1.000000    0.623116
# ins_losses         0.623116    1.000000

# %%
sns.heatmap(crash_mx, annot=True, cmap="Blues")
# Out:
# <AxesSubplot:>

# %%
df3=df3.pivot_table(index="month",columns="year",values="passengers")
df3
# Out:
# year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419
# Apr     129   135   163   181   235   227   269   313   348   348   396   461
# May     121   125   172   183   229   234   270   318   355   363   420   472
# Jun     135   149   178   218   243   264   315   374   422   435   472   535
# Jul     148   170   199   230   264   302   364   413   465   491   548   622
# Aug     148   170   199   242   272   293   347   405   467   505   559   606
# Sep     136   158   184   209   237   259   312   355   404   404   463   508
# Oct     119   133   162   191   211   229   274   306   347   359   407   461
# Nov     104   114   146   172   180   203   237   271   305   310   362   390
# ...

# %%
sns.heatmap(df3, cmap="Reds", linecolor="white", linewidth=1)
# Out:
# <AxesSubplot:xlabel='year', ylabel='month'>

# %% [markdown]
# ## Cluster Map

# %%
iris = sns.load_dataset("iris")
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
species=iris.pop("species")
sns.clustermap(iris)

# %%
sns.clustermap(df3, cmap='Blues', standard_scale=1) 
# Similarity Analysis
# x axis for smaples
#y for genes to analysize
#x look for color to identify similarity
# y look for diffferences of distance for 2 genes
# euclidian / manhatan

# %% [markdown]
# ## Pair grid

# %%
iris = sns.load_dataset("iris")
iris_g=sns.PairGrid(iris, hue = "species")
#iris_g.map(plt.scatter )
iris_g.map_diag(plt.hist)
iris_g.map_offdiag(plt.scatter)
iris_g.map_upper(plt.scatter) #upper triangle
iris_g.map_lower(sns.kdeplot) #lower triangle

# %%
iris_g= sns.PairGrid(iris, hue="species",
                     x_vars=["sepal_length","sepal_width"],
                     y_vars=["petal_length","petal_width"]
                    )
# control parigrid size
iris_g.map(plt.scatter)

# %% [markdown]
# ## Fecet Grid

# %%
df2
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tip_fg=sns.FacetGrid(df2,col="time",hue='smoker',height=4, aspect=1.3,
                    col_order=["Dinner","Lunch"],palette="rocket"
                    )
#set grid:
#         col = grids according to 
#         hue= culters in graph
#         .map(mapping method, x, y)
tip_fg.map(plt.scatter,'total_bill',"tip")

# %%
kws= dict(s=50, linewidth=.5, edgecolor="w")
tip_fg=sns.FacetGrid(df2,col="sex",hue='smoker',height=4, aspect=1.3,
                    hue_order=["Yes","No"],
                    hue_kws=dict(marker=["^","v"])
                    )
tip_fg.map(plt.scatter,'total_bill',"tip")

# %%
att_df= sns.load_dataset("attention")
att_df
# Out:
#     Unnamed: 0  subject attention  solutions  score
# 0            0        1   divided          1    2.0
# 1            1        2   divided          1    3.0
# 2            2        3   divided          1    3.0
# 3            3        4   divided          1    5.0
# 4            4        5   divided          1    4.0
# 5            5        6   divided          1    5.0
# 6            6        7   divided          1    5.0
# 7            7        8   divided          1    5.0
# 8            8        9   divided          1    2.0
# 9            9       10   divided          1    6.0
# 10          10       11   focused          1    6.0
# 11          11       12   focused          1    8.0
# 12          12       13   focused          1    6.0
# 13          13       14   focused          1    8.0
# 14          14       15   focused          1    8.0
# 15          15       16   focused          1    6.0
# 16          16       17   focused          1    7.0
# ...

# %%
att_fg= sns.FacetGrid(att_df, col="subject",
                      col_wrap=5,
                     height=1.5
                     )
att_fg.map(plt.bar ,"solutions","score")

# %% [markdown]
# # Regression Plot

# %%
df2
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
plt.figure(figsize=[8,6])
sns.set_context("paper",font_scale=1.4)
sns.lmplot(x="total_bill", y="tip", hue="sex",
           data=df2, markers=["o","*"],
           scatter_kws={"s":100,"linewidth":0.5}
          )

# %% [markdown]
# ## seperate regression plot

# %%
sns.lmplot(x="total_bill", y="tip", col="sex",row="time",
           data=df2,
           scatter_kws={"s":100,"linewidth":0.5}
          )
