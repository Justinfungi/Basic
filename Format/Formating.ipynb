# %% [raw]
# __This text to appear in bold__

# %% [markdown]
# __This text to appear in bold__

# %% [raw]
# _This text to appear in Italics_

# %% [markdown]
# _This text to appear in Italics_

# %% [raw]
# i can <br>
# can <br>
# divide <br>

# %% [markdown]
# i can <br>
# can <br>
# divide <br>

# %% [raw]
# # Heading
# ## Heading
# ### Heading
# #### Heading

# %% [markdown]
# # Heading
# ## Heading
# ### Heading
# #### Heading

# %% [raw]
# <font color=Red>  i am text</font>

# %% [markdown]
# <font color=Red>  i am text</font>

# %% [raw]
# ***

# %% [markdown]
# ***

# %% [markdown]
# 1. list1
# 2. list2
#  1. sublist1
#  2. sublist2
# 3. list3
# - list4

# %% [markdown]
# > this is indented text

# %% [markdown]
# `this is monospace font`<br>
# this is monospace font

# %% [markdown]
# $x = x + y$

# %% [markdown]
# [link](#section2)
#
# Click on the link above to jump down to bottom of page

# %% [raw]
# [link](#section2)
#
# Click on the link above to jump down to bottom of page

# %% [markdown]
# <a id="section2"></a>
#
# Write sample code to jump tp this area

# %% [raw]
# <a id="section2"></a>
#
# Write sample code to jump tp this area

# %% [markdown]
# [click me](http://google.com)

# %% [raw]
# [click me](http://google.com)

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('RBSGKlAvoiM', width=800, height=500)

# %%
from IPython.display import IFrame
IFrame('https://medium.com/analytics-vidhya/the-jupyter-notebook-formatting-guide-873ab39f765e', width = 800, height = 450)
# Out:
#         <iframe
#             width="800"
#             height="450"
#             src="https://medium.com/analytics-vidhya/the-jupyter-notebook-formatting-guide-873ab39f765e"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
from IPython.display import IFrame
IFrame('https://www.w3.ord/WAI/ER/tests/xhtml/testfiles/resources/pdf/dummy.pdf', width = 800, height = 450)
# Out:
#         <iframe
#             width="800"
#             height="450"
#             src="https://www.w3.ord/WAI/ER/tests/xhtml/testfiles/resources/pdf/dummy.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
# !pip install jupyterthemes
# Out:
# ...
#      |████████████████████████████████| 7.0 MB 7.2 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 46 kB 4.1 MB/s eta 0:00:011
# ...

# %%
# !jt -l
# Out:
# Available Themes:
#    chesterish
#    grade3
#    gruvboxd
#    gruvboxl
#    monokai
#    oceans16
#    onedork
#    solarizedd
#    solarizedl

# %%
# !jt -t chesterish -f fira -fs 10 -nf ptsans -nfs 11 -N -kl -cursw 2 -cursc r -cellw 95% -T

# %%
# !jt -r
# Out:
# Reset css and font defaults in:
# /Users/xiaokeai/.jupyter/custom &
# /Users/xiaokeai/Library/Jupyter/nbextensions

# %%
# !conda install -c conda-forge jupyter_nbextensions_configurator
# Out:
# ...
# Solving environment: \
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - defaults/noarch::conda-pack==0.6.0=pyhd3eb1b0_0
#   - defaults/noarch::jupyterlab_server==2.8.2=pyhd3eb1b0_0
#   - defaults/noarch::cookiecutter==1.7.2=pyhd3eb1b0_0
#   - defaults/osx-64::astroid==2.6.6=py39hecd8cb5_0
#   - defaults/osx-64::numba==0.54.1=py39hae1ba45_0
#   - defaults/osx-64::jupyter==1.0.0=py39hecd8cb5_7
#   - defaults/noarch::python-lsp-black==1.0.0=pyhd3eb1b0_0
#   - defaults/osx-64::gevent==21.8.0=py39h9ed2024_1
#   - defaults/osx-64::zope.event==4.5.0=py39hecd8cb5_0
#   - defaults/noarch::nbclient==0.5.3=pyhd3eb1b0_0
#   - defaults/noarch::conda-repo-cli==1.0.4=pyhd3eb1b0_0
#   - defaults/noarch::backports.functools_lru_cache==1.6.4=pyhd3eb1b0_0
#   - defaults/osx-64::nbconvert==6.1.0=py39hecd8cb5_0
#   - defaults/osx-64::ipykernel==6.4.1=py39hecd8cb5_1
# ...
