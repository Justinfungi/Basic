# %%
from PIL import Image
with Image.open("/Users/zhangdemei/Desktop/ProgrammingAtom/螢幕快照 2022-06-06 上午11.44.29.png") as im:
    im.rotate(45).show()
# interact with OS

# %%
from IPython.display import Image
Image(filename="./螢幕快照 2022-06-06 上午11.44.29.png")
